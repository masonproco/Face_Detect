# %% [markdown]
# <a href="https://colab.research.google.com/github/masonproco/Face_Detect/blob/master/HW2/Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1

# %% [markdown]
# For the first equation, we use $x + 2x^2 + 2*y + 10$

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)

f1 = x + 2*x*x + y*2 + 10
f1_min = (-0.25) + 2 * (-0.25) * (-0.25) + 10

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot3D(x, y, f1, 'gray')
ax.plot([-0.25], [0], [f1_min], '-ro')
ax.text(-0.25, -3, f1_min, "Minimum")

f1_new = X + 2*X*X + Y*2 + 10

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, f1_new, 100, colors = 'blue')
ax.plot([-0.25], [0], [f1_min], '-ro')
ax.text(2, 0, f1_min, "Minimum")

fig = plt.figure()

plt.contourf(X, Y, f1_new, 100, cmap='RdGy')
plt.colorbar()

# %% [markdown]
# For the second equation, we just take the negative, so we have $-(𝑥+2𝑥2+2∗𝑦+10)$

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)

f2 = -(x + 2*x*x + y*2 + 10)
f2_min = -((-0.25) + 2 * (-0.25) * (-0.25) + 10)

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot3D(x, y, f2, 'gray')
ax.plot([-0.25], [0], [f2_min], '-ro')
ax.text(-0.25, -3, f2_min, "Maximum")

f2_new = -(X + 2*X*X + Y*2 + 10)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, f2_new, 100, colors = 'blue')
ax.plot([0.25], [0], [f2_min], '-ro')
ax.text(-1, 0, 0, "Maximum")

fig = plt.figure()

plt.contourf(X, Y, f2_new, 100, cmap='RdGy')
plt.colorbar()

# %% [markdown]
# For our final equation, we use $y^2 - x^2$

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)

f3 = (y*y - x*x)
f3_min = 0

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot3D(x, y, f3, 'gray')
ax.plot([0], [0], [f3_min], '-ro')
ax.text(-0.25, -3, f3_min, "Maximum")

f3_new = (Y*Y - X*X)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, f3_new, 100, colors = 'blue')
ax.plot([0], [0], [f3_min], '-ro')
ax.text(-1, 0, 0, "Maximum")

fig = plt.figure()

plt.contourf(X, Y, f3_new, 100, cmap='RdGy')
plt.colorbar()
